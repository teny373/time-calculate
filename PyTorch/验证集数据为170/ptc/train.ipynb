# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Feb 20 13:38:16 2023

@author: Lenovo
"""

import time
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader
import torchvision.models as models
import torch.nn as nn
import torch

print("是否使用GPU训练：{}".format(torch.cuda.is_available()))    #打印是否采用gpu训练
if torch.cuda.is_available:
    print("GPU名称为：{}".format(torch.cuda.get_device_name()))  #打印相应的gpu信息
normalize=transforms.Normalize(mean=[5,5,5], std=[5,5,5]) #规范化
transform=transforms.Compose([transforms.Resize((64, 64)),transforms.ToTensor(),normalize]) #数据处理
dataset_train=ImageFolder('add_label/label_picture/train',transform=transform)     #训练数据集
# print(dataset_tran[0])
dataset_test=ImageFolder('add_label/label_picture/test',transform=transform)     #验证或测试数据集
dataset_valid=ImageFolder('add_label/label_picture/valid',transform=transform)

# print(dataset_train.classer)#返回类别
print(dataset_train.class_to_idx)                               #返回类别及其索引
# print(dataset_train.imgs)#返回图片路径
print(dataset_test.class_to_idx)
print(dataset_valid.class_to_idx)
train_data_size=len(dataset_train)                              #放回数据集长度
test_data_size=len(dataset_test)
valid_data_size=len(dataset_valid)
print("训练数据集的长度为：{}".format(train_data_size))
print("测试数据集的长度为：{}".format(test_data_size))
print("验证数据集的长度为：{}".format(test_data_size))
#torch自带的标准数据集加载函数
dataloader_train=DataLoader(dataset_train,batch_size=4,shuffle=True,num_workers=0,drop_last=True)
dataloader_test=DataLoader(dataset_test,batch_size=4,shuffle=True,num_workers=0,drop_last=True)
dataloader_valid=DataLoader(dataset_valid,batch_size=4,shuffle=True,num_workers=0,drop_last=True)
#模型加载
model_ft=models.resnet50(pretrained=True)#使用迁移学习，加载预训练权重
# print(model_ft)

in_features=model_ft.fc.in_features
model_ft.fc=nn.Sequential(nn.Linear(in_features,36),nn.Linear(36,4))#将最后的全连接改为（36，6），使输出为六个小数，对应四个树种的置信度


model_ft=model_ft.cuda()#将模型迁移到gpu

#pytorch2.0编译模型部分
# model_ft=torch.compile(model_ft)

#优化器
loss_fn=nn.CrossEntropyLoss()

loss_fn=loss_fn.cuda()  #将loss迁移到gpu
learn_rate=0.0001       #设置学习率
optimizer=torch.optim.SGD(model_ft.parameters(),lr=learn_rate,momentum=0.001)#可调超参数


total_train_step=0
total_test_step=0
total_valid_step=0

epoch=50              #迭代次数
writer=SummaryWriter("logs")
best_acc=-1
ss_time=time.time()

for i in range(epoch):
    start_time = time.time()
    print("--------第{}轮训练开始---------".format(i+1))
    model_ft.train()
    for data in dataloader_train:
        imgs,targets=data
        imgs=imgs.cuda()
        targets=targets.cuda()
        outputs=model_ft(imgs)
        loss=loss_fn(outputs,targets)

        optimizer.zero_grad()   #梯度归零
        loss.backward()         #反向传播计算梯度
        optimizer.step()        #梯度优化

        total_train_step=total_train_step+1
        if total_train_step%100==0:#一轮时间过长可以考虑加一个
            end_time=time.time()
            print("使用GPU训练100次的时间为：{}".format(end_time-start_time))
            print("训练次数：{},loss:{}".format(total_train_step,loss.item()))

    model_ft.eval()
    
    total_test_loss=0
    total_test_accuracy=0
    
    total_train_loss=0
    total_train_accuracy=0

    total_valid_loss = 0
    total_valid_accuracy = 0
    with torch.no_grad():       #验证数据集时禁止反向传播优化权重
      #记录训练集精度和损失值
        for data in dataloader_train:
            imgs,targets=data
            imgs = imgs.cuda()
            targets = targets.cuda()
            outputs=model_ft(imgs)
            train_loss=loss_fn(outputs,targets)
            total_train_loss=total_train_loss+train_loss.item()
            train_accuracy=(outputs.argmax(1)==targets).sum()
            total_train_accuracy=total_train_accuracy+train_accuracy
        print("整体训练集上的loss：{}(越小越好,与上面的loss无关此为测试集的总loss)".format(total_train_loss))
        print("整体训练集上的正确率：{}(越大越好)".format(total_train_accuracy / len(dataset_train)))
       
        for data in dataloader_test:
            imgs,targets=data
            imgs = imgs.cuda()
            targets = targets.cuda()
            outputs=model_ft(imgs)
            test_loss=loss_fn(outputs,targets)
            total_test_loss=total_test_loss+test_loss.item()
            test_accuracy=(outputs.argmax(1)==targets).sum()
            total_test_accuracy=total_test_accuracy+test_accuracy
        print("整体测试集上的loss：{}(越小越好,与上面的loss无关此为测试集的总loss)".format(total_test_loss))
        print("整体测试集上的正确率：{}(越大越好)".format(total_test_accuracy / len(dataset_test)))

        for data in dataloader_valid:
            imgs, targets = data
            imgs = imgs.cuda()
            targets = targets.cuda()
            outputs = model_ft(imgs)
            valid_loss = loss_fn(outputs, targets)
            total_valid_loss = total_valid_loss + valid_loss.item()
            valid_accuracy = (outputs.argmax(1) == targets).sum()
            total_valid_accuracy = total_valid_accuracy + valid_accuracy
        print("整体验证集上的loss：{}(越小越好,与上面的loss无关此为测试集的总loss)".format(total_valid_loss))
        print("整体验证集上的正确率：{}(越大越好)".format(total_valid_accuracy / len(dataset_valid)))

        # 记录到 TensorBoard
        writer.add_scalar("Train Accuracy", total_train_accuracy / len(dataset_train), i)
        writer.add_scalar("Train Loss", total_train_loss, i)
        writer.add_scalar("Test Accuracy", total_test_accuracy/len(dataset_test), i)
        writer.add_scalar("Test Loss", total_test_loss, i)
        writer.add_scalar("Valid Accuracy", total_valid_accuracy / len(dataset_valid), i)
        writer.add_scalar("Valid Loss", total_valid_loss, i)

        total_test_step = total_test_step + 1
        if total_test_accuracy > best_acc:   #保存迭代次数中最好的模型
            print("已修改模型")
            best_acc = total_test_accuracy
            torch.save(model_ft.state_dict(), "best_model.pth")      #只保留权重的参数即可 
# # 绘制训练和测试精度和损失曲线
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
# plt.plot(total_train_loss, label='Train Loss')
# plt.plot(total_test_loss, label='Test Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()


# plt.subplot(1, 2, 2)
# plt.plot(total_train_accuracy / len(dataset_train), label='Train Accuracy')
# plt.plot(total_test_accuracy/len(dataset_test), label='Test Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy (%)')
# plt.legend()
# plt.show()
ee_time=time.time()
zong_time=ee_time-ss_time
print("训练总共用时:{}h:{}m:{}s".format(int(zong_time//3600),int((zong_time%3600)//60),int(zong_time%60))) #打印训练总耗时
writer.close()
# Out:
# 是否使用GPU训练：True
# GPU名称为：NVIDIA GeForce RTX 4060 Ti
# {'fir': 0, 'pine': 1, 'spruce': 2, 'trembling aspen': 3}
# {'fir': 0, 'pine': 1, 'spruce': 2, 'trembling aspen': 3}
# {'fir': 0, 'pine': 1, 'spruce': 2, 'trembling aspen': 3}
# 训练数据集的长度为：597
# 测试数据集的长度为：85
# 验证数据集的长度为：85
# /venv/main/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /venv/main/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# --------第1轮训练开始---------
# 使用GPU训练100次的时间为：3.6568214893341064
# 训练次数：100,loss:1.3547441959381104
# 整体训练集上的loss：202.92169106006622(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.30485761165618896(越大越好)
# 整体测试集上的loss：28.36172652244568(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.29411765933036804(越大越好)
# 整体验证集上的loss：56.679781794548035(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.3294117748737335(越大越好)
# 已修改模型
# --------第2轮训练开始---------
# 使用GPU训练100次的时间为：1.694918155670166
# 训练次数：200,loss:1.5125455856323242
# 整体训练集上的loss：201.03995007276535(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.3366834223270416(越大越好)
# 整体测试集上的loss：28.797962188720703(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3294117748737335(越大越好)
# 整体验证集上的loss：56.9304895401001(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.30588236451148987(越大越好)
# 已修改模型
# --------第3轮训练开始---------
# 使用GPU训练100次的时间为：0.05579423904418945
# 训练次数：300,loss:1.4746609926223755
# 使用GPU训练100次的时间为：2.9517948627471924
# 训练次数：400,loss:1.2638483047485352
# 整体训练集上的loss：198.63195610046387(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.34170854091644287(越大越好)
# 整体测试集上的loss：26.97213387489319(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.43529412150382996(越大越好)
# 整体验证集上的loss：56.13571071624756(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.3117647171020508(越大越好)
# 已修改模型
# --------第4轮训练开始---------
# 使用GPU训练100次的时间为：1.8163650035858154
# 训练次数：500,loss:1.3557255268096924
# 整体训练集上的loss：193.57410567998886(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.37353432178497314(越大越好)
# 整体测试集上的loss：26.123721480369568(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4000000059604645(越大越好)
# 整体验证集上的loss：53.602041840553284(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.3588235378265381(越大越好)
# --------第5轮训练开始---------
# 使用GPU训练100次的时间为：0.10811257362365723
# 训练次数：600,loss:1.1109490394592285
# 使用GPU训练100次的时间为：3.4827516078948975
# 训练次数：700,loss:1.3229011297225952
# 整体训练集上的loss：193.23999959230423(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.3534338176250458(越大越好)
# 整体测试集上的loss：27.016189336776733(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# 整体验证集上的loss：54.639490604400635(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.4000000059604645(越大越好)
# --------第6轮训练开始---------
# 使用GPU训练100次的时间为：1.8679966926574707
# 训练次数：800,loss:1.165953278541565
# 整体训练集上的loss：188.21847653388977(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.3953098654747009(越大越好)
# 整体测试集上的loss：25.313015818595886(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.43529412150382996(越大越好)
# 整体验证集上的loss：53.028499245643616(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.3529411852359772(越大越好)
# --------第7轮训练开始---------
# 使用GPU训练100次的时间为：0.2017505168914795
# 训练次数：900,loss:1.1188806295394897
# 使用GPU训练100次的时间为：3.6202523708343506
# 训练次数：1000,loss:1.1089895963668823
# 整体训练集上的loss：181.94615507125854(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4154103696346283(越大越好)
# 整体测试集上的loss：25.867471277713776(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3529411852359772(越大越好)
# 整体验证集上的loss：51.14286333322525(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.34705883264541626(越大越好)
# --------第8轮训练开始---------
# 使用GPU训练100次的时间为：1.9193623065948486
# 训练次数：1100,loss:1.2862056493759155
# 整体训练集上的loss：183.06995689868927(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4271356761455536(越大越好)
# 整体测试集上的loss：26.36168509721756(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4000000059604645(越大越好)
# 整体验证集上的loss：52.46434736251831(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.4000000059604645(越大越好)
# --------第9轮训练开始---------
# 使用GPU训练100次的时间为：0.2699775695800781
# 训练次数：1200,loss:1.2610282897949219
# 使用GPU训练100次的时间为：3.685619354248047
# 训练次数：1300,loss:1.0237329006195068
# 整体训练集上的loss：175.82659900188446(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.500837504863739(越大越好)
# 整体测试集上的loss：24.691661953926086(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.43529412150382996(越大越好)
# 整体验证集上的loss：50.664284229278564(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.4000000059604645(越大越好)
# --------第10轮训练开始---------
# 使用GPU训练100次的时间为：1.9916317462921143
# 训练次数：1400,loss:1.0023784637451172
# 整体训练集上的loss：180.93349069356918(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4371859133243561(越大越好)
# 整体测试集上的loss：24.442441046237946(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4117647111415863(越大越好)
# 整体验证集上的loss：50.08517545461655(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.44117647409439087(越大越好)
# --------第11轮训练开始---------
# 使用GPU训练100次的时间为：0.33885693550109863
# 训练次数：1500,loss:1.492614507675171
# 使用GPU训练100次的时间为：3.743786573410034
# 训练次数：1600,loss:1.1305856704711914
# 整体训练集上的loss：172.90200781822205(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5159128904342651(越大越好)
# 整体测试集上的loss：24.856916189193726(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4588235318660736(越大越好)
# 整体验证集上的loss：48.951816737651825(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.4588235318660736(越大越好)
# 已修改模型
# --------第12轮训练开始---------
# 使用GPU训练100次的时间为：2.0598840713500977
# 训练次数：1700,loss:0.9571396112442017
# 整体训练集上的loss：162.28171652555466(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5594639778137207(越大越好)
# 整体测试集上的loss：23.025536119937897(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# 整体验证集上的loss：47.209787011146545(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.4882352948188782(越大越好)
# 已修改模型
# --------第13轮训练开始---------
# 使用GPU训练100次的时间为：0.4105224609375
# 训练次数：1800,loss:1.226682424545288
# 使用GPU训练100次的时间为：3.833688735961914
# 训练次数：1900,loss:1.172309160232544
# 整体训练集上的loss：162.33926105499268(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5929648280143738(越大越好)
# 整体测试集上的loss：23.478729724884033(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6117647290229797(越大越好)
# 整体验证集上的loss：46.44683700799942(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5823529362678528(越大越好)
# 已修改模型
# --------第14轮训练开始---------
# 使用GPU训练100次的时间为：2.1584391593933105
# 训练次数：2000,loss:1.0621685981750488
# 整体训练集上的loss：160.73157054185867(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6164153814315796(越大越好)
# 整体测试集上的loss：23.25425374507904(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5647059082984924(越大越好)
# 整体验证集上的loss：47.352142691612244(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5176470875740051(越大越好)
# --------第15轮训练开始---------
# 使用GPU训练100次的时间为：0.47530245780944824
# 训练次数：2100,loss:1.0493268966674805
# 使用GPU训练100次的时间为：3.8574371337890625
# 训练次数：2200,loss:1.1267951726913452
# 整体训练集上的loss：160.75692737102509(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6113902926445007(越大越好)
# 整体测试集上的loss：24.178488552570343(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.529411792755127(越大越好)
# 整体验证集上的loss：48.34042435884476(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5235294103622437(越大越好)
# --------第16轮训练开始---------
# 使用GPU训练100次的时间为：2.2123773097991943
# 训练次数：2300,loss:1.1063222885131836
# 整体训练集上的loss：151.42674177885056(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6984924674034119(越大越好)
# 整体测试集上的loss：22.24075937271118(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6352941393852234(越大越好)
# 整体验证集上的loss：45.13455665111542(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5941176414489746(越大越好)
# 已修改模型
# --------第17轮训练开始---------
# 使用GPU训练100次的时间为：0.5425302982330322
# 训练次数：2400,loss:1.1807596683502197
# 使用GPU训练100次的时间为：3.9937925338745117
# 训练次数：2500,loss:1.20632004737854
# 整体训练集上的loss：170.1723656654358(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.572864294052124(越大越好)
# 整体测试集上的loss：24.99955713748932(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.529411792755127(越大越好)
# 整体验证集上的loss：48.7835431098938(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.47647058963775635(越大越好)
# --------第18轮训练开始---------
# 使用GPU训练100次的时间为：2.262946605682373
# 训练次数：2600,loss:1.1133924722671509
# 整体训练集上的loss：143.1149163544178(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6917923092842102(越大越好)
# 整体测试集上的loss：21.96535474061966(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6235294342041016(越大越好)
# 整体验证集上的loss：43.070062041282654(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6529411673545837(越大越好)
# --------第19轮训练开始---------
# 使用GPU训练100次的时间为：0.6151144504547119
# 训练次数：2700,loss:0.8226369619369507
# 使用GPU训练100次的时间为：3.9893441200256348
# 训练次数：2800,loss:0.9159491062164307
# 整体训练集上的loss：172.68910348415375(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5226130485534668(越大越好)
# 整体测试集上的loss：24.28514701128006(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.43529412150382996(越大越好)
# 整体验证集上的loss：46.837459683418274(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5(越大越好)
# --------第20轮训练开始---------
# 使用GPU训练100次的时间为：2.3525328636169434
# 训练次数：2900,loss:0.9712628722190857
# 整体训练集上的loss：153.35054224729538(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6164153814315796(越大越好)
# 整体测试集上的loss：22.67387068271637(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5647059082984924(越大越好)
# 整体验证集上的loss：43.40891736745834(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6000000238418579(越大越好)
# --------第21轮训练开始---------
# 使用GPU训练100次的时间为：0.6948196887969971
# 训练次数：3000,loss:0.6676231026649475
# 使用GPU训练100次的时间为：4.121527433395386
# 训练次数：3100,loss:0.6570335626602173
# 整体训练集上的loss：190.98871445655823(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.38860970735549927(越大越好)
# 整体测试集上的loss：27.27564638853073(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.38823530077934265(越大越好)
# 整体验证集上的loss：53.70728254318237(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.3764705955982208(越大越好)
# --------第22轮训练开始---------
# 使用GPU训练100次的时间为：2.4468941688537598
# 训练次数：3200,loss:0.6727073788642883
# 整体训练集上的loss：120.34158490598202(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7286431789398193(越大越好)
# 整体测试集上的loss：20.237025320529938(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6000000238418579(越大越好)
# 整体验证集上的loss：38.80518478155136(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6647058725357056(越大越好)
# --------第23轮训练开始---------
# 使用GPU训练100次的时间为：0.754244327545166
# 训练次数：3300,loss:0.6046907901763916
# 使用GPU训练100次的时间为：4.167560577392578
# 训练次数：3400,loss:1.3465181589126587
# 整体训练集上的loss：140.04751634597778(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7118927836418152(越大越好)
# 整体测试集上的loss：22.10810387134552(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5882353186607361(越大越好)
# 整体验证集上的loss：42.458354353904724(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6117647290229797(越大越好)
# --------第24轮训练开始---------
# 使用GPU训练100次的时间为：2.5071187019348145
# 训练次数：3500,loss:0.6152998208999634
# 整体训练集上的loss：181.31152313947678(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5041875839233398(越大越好)
# 整体测试集上的loss：26.334100663661957(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4470588266849518(越大越好)
# 整体验证集上的loss：51.851680755615234(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5117647051811218(越大越好)
# --------第25轮训练开始---------
# 使用GPU训练100次的时间为：0.8092446327209473
# 训练次数：3600,loss:1.2996803522109985
# 使用GPU训练100次的时间为：4.176005125045776
# 训练次数：3700,loss:0.5439021587371826
# 整体训练集上的loss：123.94651040434837(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7571189403533936(越大越好)
# 整体测试集上的loss：20.024839222431183(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6352941393852234(越大越好)
# 整体验证集上的loss：40.292298316955566(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6411764621734619(越大越好)
# --------第26轮训练开始---------
# 使用GPU训练100次的时间为：2.51828932762146
# 训练次数：3800,loss:0.5661137104034424
# 整体训练集上的loss：170.07795882225037(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.500837504863739(越大越好)
# 整体测试集上的loss：24.672011494636536(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# 整体验证集上的loss：48.96766901016235(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5176470875740051(越大越好)
# --------第27轮训练开始---------
# 使用GPU训练100次的时间为：0.890862226486206
# 训练次数：3900,loss:0.814075767993927
# 使用GPU训练100次的时间为：4.230890989303589
# 训练次数：4000,loss:0.9398231506347656
# 整体训练集上的loss：156.84965413808823(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6147403717041016(越大越好)
# 整体测试集上的loss：23.044804275035858(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5529412031173706(越大越好)
# 整体验证集上的loss：46.18496644496918(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.570588231086731(越大越好)
# --------第28轮训练开始---------
# 使用GPU训练100次的时间为：2.638021945953369
# 训练次数：4100,loss:0.7338132858276367
# 整体训练集上的loss：142.19032868742943(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6884422302246094(越大越好)
# 整体测试集上的loss：21.820938885211945(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5764706134796143(越大越好)
# 整体验证集上的loss：42.29049241542816(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6529411673545837(越大越好)
# --------第29轮训练开始---------
# 使用GPU训练100次的时间为：0.9415264129638672
# 训练次数：4200,loss:0.7777136564254761
# 使用GPU训练100次的时间为：4.238367795944214
# 训练次数：4300,loss:0.784003496170044
# 整体训练集上的loss：116.44772616028786(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.8073701858520508(越大越好)
# 整体测试集上的loss：20.04923391342163(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6823529601097107(越大越好)
# 整体验证集上的loss：40.16898500919342(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6352941393852234(越大越好)
# 已修改模型
# --------第30轮训练开始---------
# 使用GPU训练100次的时间为：2.392697334289551
# 训练次数：4400,loss:0.5456143021583557
# 整体训练集上的loss：183.68953400850296(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4422110617160797(越大越好)
# 整体测试集上的loss：25.86288046836853(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.42352941632270813(越大越好)
# 整体验证集上的loss：50.70518600940704(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.44117647409439087(越大越好)
# --------第31轮训练开始---------
# 使用GPU训练100次的时间为：0.969398021697998
# 训练次数：4500,loss:0.5532394647598267
# 使用GPU训练100次的时间为：4.38869833946228
# 训练次数：4600,loss:1.2826892137527466
# 整体训练集上的loss：115.6300697028637(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7185929417610168(越大越好)
# 整体测试集上的loss：18.743268847465515(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.658823549747467(越大越好)
# 整体验证集上的loss：38.6380318403244(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6352941393852234(越大越好)
# --------第32轮训练开始---------
# 使用GPU训练100次的时间为：2.7816293239593506
# 训练次数：4700,loss:0.4909527897834778
# 整体训练集上的loss：128.31905663013458(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7068676352500916(越大越好)
# 整体测试集上的loss：20.476742565631866(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6000000238418579(越大越好)
# 整体验证集上的loss：41.598729610443115(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5823529362678528(越大越好)
# --------第33轮训练开始---------
# 使用GPU训练100次的时间为：1.0830798149108887
# 训练次数：4800,loss:0.38075071573257446
# 使用GPU训练100次的时间为：4.469070196151733
# 训练次数：4900,loss:0.8689345121383667
# 整体训练集上的loss：159.0482646226883(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5628140568733215(越大越好)
# 整体测试集上的loss：24.18563199043274(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# 整体验证集上的loss：47.72481644153595(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.48235294222831726(越大越好)
# --------第34轮训练开始---------
# 使用GPU训练100次的时间为：2.840094566345215
# 训练次数：5000,loss:0.9542306065559387
# 整体训练集上的loss：156.5082225203514(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5611390471458435(越大越好)
# 整体测试集上的loss：23.456036150455475(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.529411792755127(越大越好)
# 整体验证集上的loss：45.39934080839157(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5352941155433655(越大越好)
# --------第35轮训练开始---------
# 使用GPU训练100次的时间为：1.166815996170044
# 训练次数：5100,loss:1.114093542098999
# 使用GPU训练100次的时间为：4.588046073913574
# 训练次数：5200,loss:0.5243173241615295
# 整体训练集上的loss：109.98082840442657(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7889447212219238(越大越好)
# 整体测试集上的loss：19.519066125154495(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6117647290229797(越大越好)
# 整体验证集上的loss：39.44610542058945(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5941176414489746(越大越好)
# --------第36轮训练开始---------
# 使用GPU训练100次的时间为：2.914384126663208
# 训练次数：5300,loss:0.2763268053531647
# 整体训练集上的loss：144.19607308506966(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6113902926445007(越大越好)
# 整体测试集上的loss：22.98209124803543(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# 整体验证集上的loss：42.58381724357605(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5764706134796143(越大越好)
# --------第37轮训练开始---------
# 使用GPU训练100次的时间为：1.2363617420196533
# 训练次数：5400,loss:0.5111982226371765
# 使用GPU训练100次的时间为：4.633559703826904
# 训练次数：5500,loss:0.42516225576400757
# 整体训练集上的loss：119.63436338305473(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7001674771308899(越大越好)
# 整体测试集上的loss：20.466023921966553(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5647059082984924(越大越好)
# 整体验证集上的loss：39.23007017374039(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5764706134796143(越大越好)
# --------第38轮训练开始---------
# 使用GPU训练100次的时间为：2.962242841720581
# 训练次数：5600,loss:0.9232702255249023
# 整体训练集上的loss：87.36173424124718(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.8509212732315063(越大越好)
# 整体测试集上的loss：16.376690983772278(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.7411764860153198(越大越好)
# 整体验证集上的loss：32.96712813526392(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.7235293984413147(越大越好)
# 已修改模型
# --------第39轮训练开始---------
# 使用GPU训练100次的时间为：1.3127238750457764
# 训练次数：5700,loss:0.9878559708595276
# 使用GPU训练100次的时间为：4.7927491664886475
# 训练次数：5800,loss:1.228687047958374
# 整体训练集上的loss：83.90026810765266(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.8609715104103088(越大越好)
# 整体测试集上的loss：17.073755860328674(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.7058823704719543(越大越好)
# 整体验证集上的loss：34.972840666770935(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6705882549285889(越大越好)
# --------第40轮训练开始---------
# 使用GPU训练100次的时间为：3.0843095779418945
# 训练次数：5900,loss:0.8421960473060608
# 整体训练集上的loss：130.83446955680847(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6733668446540833(越大越好)
# 整体测试集上的loss：22.145606964826584(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# 整体验证集上的loss：41.13538175821304(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6058823466300964(越大越好)
# --------第41轮训练开始---------
# 使用GPU训练100次的时间为：1.387497901916504
# 训练次数：6000,loss:0.6311618685722351
# 使用GPU训练100次的时间为：4.838507652282715
# 训练次数：6100,loss:0.6686514616012573
# 整体训练集上的loss：131.15632858872414(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6901172399520874(越大越好)
# 整体测试集上的loss：21.870476603507996(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5647059082984924(越大越好)
# 整体验证集上的loss：41.55656662583351(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6176470518112183(越大越好)
# --------第42轮训练开始---------
# 使用GPU训练100次的时间为：3.10603666305542
# 训练次数：6200,loss:0.8098543882369995
# 整体训练集上的loss：106.87849044799805(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.805695116519928(越大越好)
# 整体测试集上的loss：18.757901579141617(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6941176652908325(越大越好)
# 整体验证集上的loss：36.92071771621704(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6647058725357056(越大越好)
# --------第43轮训练开始---------
# 使用GPU训练100次的时间为：1.4341189861297607
# 训练次数：6300,loss:0.6452131271362305
# 使用GPU训练100次的时间为：4.898704767227173
# 训练次数：6400,loss:0.20098784565925598
# 整体训练集上的loss：88.20322252810001(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.8944723606109619(越大越好)
# 整体测试集上的loss：17.216809511184692(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.7176470756530762(越大越好)
# 整体验证集上的loss：36.109231159090996(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6529411673545837(越大越好)
# --------第44轮训练开始---------
# 使用GPU训练100次的时间为：3.222461700439453
# 训练次数：6500,loss:0.7012282609939575
# 整体训练集上的loss：159.85399451851845(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5393635034561157(越大越好)
# 整体测试集上的loss：25.448079377412796(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.43529412150382996(越大越好)
# 整体验证集上的loss：46.6256388425827(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5176470875740051(越大越好)
# --------第45轮训练开始---------
# 使用GPU训练100次的时间为：1.5143625736236572
# 训练次数：6600,loss:1.8141467571258545
# 使用GPU训练100次的时间为：4.84916877746582
# 训练次数：6700,loss:0.6584182977676392
# 整体训练集上的loss：159.82095846533775(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5376884341239929(越大越好)
# 整体测试集上的loss：23.917943120002747(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5411764979362488(越大越好)
# 整体验证集上的loss：46.603061735630035(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.4941176474094391(越大越好)
# --------第46轮训练开始---------
# 使用GPU训练100次的时间为：3.2568068504333496
# 训练次数：6800,loss:0.42868223786354065
# 整体训练集上的loss：58.77027180045843(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.9112227559089661(越大越好)
# 整体测试集上的loss：13.21485897898674(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.7647058963775635(越大越好)
# 整体验证集上的loss：32.122013956308365(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.699999988079071(越大越好)
# 已修改模型
# --------第47轮训练开始---------
# 使用GPU训练100次的时间为：1.5619776248931885
# 训练次数：6900,loss:0.3977213501930237
# 使用GPU训练100次的时间为：4.886101722717285
# 训练次数：7000,loss:0.5111932754516602
# 整体训练集上的loss：116.89075237512589(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.715242862701416(越大越好)
# 整体测试集上的loss：19.127618700265884(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6235294342041016(越大越好)
# 整体验证集上的loss：38.544007897377014(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6058823466300964(越大越好)
# --------第48轮训练开始---------
# 使用GPU训练100次的时间为：3.291501760482788
# 训练次数：7100,loss:0.21633844077587128
# 整体训练集上的loss：71.29845397919416(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.9045225977897644(越大越好)
# 整体测试集上的loss：17.027582049369812(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.6352941393852234(越大越好)
# 整体验证集上的loss：33.37624481320381(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.7117646932601929(越大越好)
# --------第49轮训练开始---------
# 使用GPU训练100次的时间为：1.6290240287780762
# 训练次数：7200,loss:1.308429479598999
# 使用GPU训练100次的时间为：4.926336288452148
# 训练次数：7300,loss:0.18973734974861145
# 整体训练集上的loss：75.41765549778938(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.8710217475891113(越大越好)
# 整体测试集上的loss：15.574855387210846(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.7529411911964417(越大越好)
# 整体验证集上的loss：34.94180083274841(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.6823529601097107(越大越好)
# --------第50轮训练开始---------
# 使用GPU训练100次的时间为：3.0320069789886475
# 训练次数：7400,loss:0.7798965573310852
# 整体训练集上的loss：98.66914750635624(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7487437129020691(越大越好)
# 整体测试集上的loss：20.34181559085846(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5764706134796143(越大越好)
# 整体验证集上的loss：41.82293623685837(越小越好,与上面的loss无关此为测试集的总loss)
# 整体验证集上的正确率：0.5823529362678528(越大越好)
# 训练总共用时:0h:6m:59s
